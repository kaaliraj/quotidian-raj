# %%
from youtube_transcript_api import YouTubeTranscriptApi
import re
import os

# %%
transcript = YouTubeTranscriptApi.get_transcript('YLbypZjHgSA')

# %%
transcript
# Out:
# [{'text': 'Hello!', 'start': 0.149, 'duration': 1.0},
#  {'text': 'My name is Rajendran!', 'start': 1.149, 'duration': 1.0},
#  {'text': 'I am launching this playlist, titled “Quotidian”,\non my YouTube Channel.',
#   'start': 2.149,
#   'duration': 3.871},
#  {'text': 'I want to meet you daily, with a little tidbit\nof interesting information.',
#   'start': 6.02,
#   'duration': 5.56},
#  {'text': 'Let me give you a brief introduction about\nwhat this is.',
#   'start': 11.58,
#   'duration': 4.089},
#  {'text': 'Let me first introduce myself to you, who\nI am, and what I do.',
#   'start': 15.669,
#   'duration': 4.761},
#  {'text': 'I am Rajendran Dandapani, and I have been\nemployed at this company called Zoho Corporation,',
#   'start': 20.43,
#   'duration': 5.89},
#  {'text': 'for the past 25 years, right from the day\nit was founded.',
#   'start': 26.32,
#   'duration': 3.469},
#  {'text': 'My current role involves managing engineers\nwho build world class software applications.',
#   'start': 29.789,
#   'duration': 4.521},
#  {'text': 'At the same time, ever since 2005, we have\nbeen running an interesting academic experiment',
#   'start': 34.31,
#   'duration': 4.68},
#  {'text': 'called “Zoho Schools”.', 'start': 38.99, 'duration': 1.0},
#  {'text': 'I teach programming, design, marketing, and\nsoft-skills at this Zoho Schools of Learning.',
#   'start': 39.99,
#   'duration': 4.87},
#  {'text': 'As I grew more mature, with age and experience,\nI have also been teaching the art of managing',
#   'start': 44.86,
#   'duration': 7.5},
#  {'text': 'to many of my colleagues.', 'start': 52.36, 'duration': 1.59},
#  {'text': 'And, at Zoho Schools, I lead a group of faculty\nmembers, in my current role as President.',
#   'start': 53.95,
#   'duration': 7.33},
#  {'text': 'So, if I step back and take a look, a typical\nday for me involves Managing, Teaching, Teaching',
#   'start': 61.28,
#   'duration': 5.2},
#  {'text': 'Managing, and Managing Teaching!', 'start': 66.48, 'duration': 1.0},
#  {'text': 'So, the stuff that I share with you every\nday, I am guessing they will fall within one',
#   'start': 67.48,
#   'duration': 13.66},
#  {'text': 'of these four boxes!', 'start': 81.14, 'duration': 1.19},
#  {'text': 'Okay!', 'start': 82.33, 'duration': 1.0},
#  {'text': 'So, what then is a Quotidian?', 'start': 83.33, 'duration': 1.0},
#  {'text': 'And, why am I even doing it?', 'start': 84.33, 'duration': 2.73},
#  {'text': 'First up, the word “Quotidian”.', 'start': 87.06, 'duration': 2.29},
#  {'text': 'The dictionary definition goes something like\nthis:- “Daily, Commonplace, Mundane”..',
#   'start': 89.35,
#   'duration': 4.58},
#  {'text': 'Something that one sees nearly every day.',
#   'start': 93.93,
#   'duration': 1.71},
#  {'text': 'The boring, the usual, the uninteresting!',
#   'start': 95.64,
#   'duration': 3.7},
#  {'text': 'So, I am setting the expectations very clearly.',
#   'start': 99.34,
#   'duration': 5.23},
#  {'text': 'It is important that you understand up front\nwhat you can expect from these!',
#   'start': 104.57,
#   'duration': 8.65},
#  {'text': 'All I am trying to do here is share with you,\nthe little nuggets, tidbits, tchotchkes, that',
#   'start': 113.22,
#   'duration': 9.98},
#  {'text': 'I encounter day to day, that I find interesting…',
#   'start': 123.2,
#   'duration': 5.459},
#  {'text': 'A “Quotidian” from me may just be that.',
#   'start': 128.659,
#   'duration': 3.771},
#  {'text': 'Quotidian!', 'start': 132.43, 'duration': 1.0},
#  {'text': 'Taking a second look at the word, one sees\nthat it is a portmanteau of “Quotes” and',
#   'start': 133.43,
#   'duration': 5.62},
#  {'text': '“Comedian”.', 'start': 139.05, 'duration': 1.0},
#  {'text': 'We will be sharing and discussing a lot of\nfamous words and quotes by historic luminaries..',
#   'start': 140.05,
#   'duration': 9.4},
#  {'text': 'And, people call me a comedian often.',
#   'start': 149.45,
#   'duration': 2.989},
#  {'text': 'An inappropriate comedian sharing noteworthy\nquotes!',
#   'start': 152.439,
#   'duration': 2.39},
#  {'text': 'That’s what you’ll get here.', 'start': 154.829, 'duration': 1.981},
#  {'text': 'If you see the number, I haven’t mentioned\nit as “1” or “01”.',
#   'start': 156.81,
#   'duration': 6.37},
#  {'text': 'I chose “001” because I wanted to tell\nmyself that this is ',
#   'start': 163.18,
#   'duration': 13.479},
#  {'text': 'a marathon.', 'start': 176.659, 'duration': 1.86},
#  {'text': 'A long game.', 'start': 178.519, 'duration': 1.19},
#  {'text': 'Set my destination far into the future.',
#   'start': 179.709,
#   'duration': 3.071},
#  {'text': 'I have thus told myself that I should take\nthis all the way to a thousand episodes!',
#   'start': 182.78,
#   'duration': 6.769},
#  {'text': 'Such explicit goal-setting and public-sharing\nmight even force me, remind me, encourage',
#   'start': 189.549,
#   'duration': 5.881},
#  {'text': 'me, egg me on, if on some day I doze off,\nmiss doing this, or feel out of sorts.',
#   'start': 195.43,
#   'duration': 7.419},
#  {'text': 'And, that’s the reason for the James-Bondish\nnumbering system!',
#   'start': 202.849,
#   'duration': 3.301},
#  {'text': 'There is a phrase in Japanese called “Kai\nZen”.',
#   'start': 206.15,
#   'duration': 3.559},
#  {'text': 'Roughly translates to “Changing for the\nBetter”.',
#   'start': 209.709,
#   'duration': 3.431},
#  {'text': 'Small changes.', 'start': 213.14, 'duration': 1.0},
#  {'text': 'Atomic changes.', 'start': 214.14, 'duration': 1.0},
#  {'text': 'Incremental improvements.', 'start': 215.14, 'duration': 1.0},
#  {'text': 'Not a dark night suddenly turning into a bright\nday.',
#   'start': 216.14,
#   'duration': 2.299},
#  {'text': 'But a gradual onset of a dawn, through fifty\nshades of grey.',
#   'start': 218.439,
#   'duration': 4.8},
#  {'text': 'Any change, any meaningful transformation,\nwill have to proceed only through gradual',
#   'start': 223.239,
#   'duration': 3.941},
#  {'text': 'steps.', 'start': 227.18, 'duration': 1.0},
#  {'text': 'Every day, to present something interesting\nto you, I need to encounter it in the first',
#   'start': 228.18,
#   'duration': 7.029},
#  {'text': 'place, assimilate, make the connections, learn\nfrom it, and share them with you!',
#   'start': 235.209,
#   'duration': 3.75},
#  {'text': 'So, it becomes a gentle positive pressure\non me to bake the “Today I Learned” phenomenon',
#   'start': 238.959,
#   'duration': 4.791},
#  {'text': 'right into my daily routine!', 'start': 243.75, 'duration': 1.0},
#  {'text': 'From the viewpoint of my wife, ever since\nthe Corona Lockdown started, I had lost motivation',
#   'start': 244.75,
#   'duration': 4.629},
#  {'text': 'to really groom myself, and the results were\nturning out shabby.',
#   'start': 249.379,
#   'duration': 4.851},
#  {'text': 'Now though, as I have to appear on camera\nin front of you every day, present to you',
#   'start': 254.23,
#   'duration': 16.14},
#  {'text': '“presentably”, I have to foam up and slide\ndown, if you know what I mean.',
#   'start': 270.37,
#   'duration': 6.079},
#  {'text': 'And, that is a clear benefit if ever there\nwas one!',
#   'start': 276.449,
#   'duration': 2.881},
#  {'text': 'Hugh Macleod, a famous author, cartoonist,\nphilosopher, overall smart guy, says “If',
#   'start': 279.33,
#   'duration': 4.86},
#  {'text': 'you are successful, it’ll usually never\ncome from the direction you predicted.',
#   'start': 284.19,
#   'duration': 3.78},
#  {'text': '(The same is true if you fail!)”.',
#   'start': 287.97,
#   'duration': 1.789},
#  {'text': 'Whatever goal or destination you chose when\nyou got started, that is usually never the',
#   'start': 289.759,
#   'duration': 4.051},
#  {'text': 'reason you succeed, that is usually never\nthe place you eventually reach.',
#   'start': 293.81,
#   'duration': 4.669},
#  {'text': 'Failure works the same way too.',
#   'start': 298.479,
#   'duration': 1.44},
#  {'text': 'Both success and failure are usually from\n“out of left field”.',
#   'start': 299.919,
#   'duration': 5.941},
#  {'text': 'I don’t have some overarching goal or purpose\nfor starting this initiative.',
#   'start': 305.86,
#   'duration': 4.279},
#  {'text': 'I want to learn something interesting everyday\nso I can share it with you.',
#   'start': 310.139,
#   'duration': 5.78},
#  {'text': 'Let’s see how it goes from here on out!',
#   'start': 315.919,
#   'duration': 6.97},
#  {'text': 'Thank you!', 'start': 322.889, 'duration': 1.411}]

# %%
""" 
read both the files the tittle and the id
save the file name as tittle followed by the id 




"""
# Out:
# ' \nread both the files the tittle and the id \n\n\n\n'

# %%
playlist_titles = "/home/kaaliraj/Downloads/quotidian-raj/quotidian-raj/transcipts-descript/quotidian-raj-title.txt"
video_id = "/home/kaaliraj/Downloads/quotidian-raj/quotidian-raj/transcipts-descript/quotidian-raj-id.txt"

# %%
title_file = open(playlist_titles, 'r')
video_file = open(video_id,'r')

# %%
pwd
# Out:
# '/home/kaaliraj/Downloads/quotidian-raj/quotidian-raj/transcipts-descript'

# %%
counter = 0
for video in video_file :
    print(counter)
    os.system("yt-dlp https://www.youtube.com/watch?v="+video.replace('\n', '')+" --write-description --skip-download --youtube-skip-dash-manifest"
)
    os.system("yt-dlp https://www.youtube.com/watch?v="+video.replace('\n', '')+" --write-sub --sub-lang en --skip-download ")
# Out:
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YLbypZjHgSA
# [youtube] YLbypZjHgSA: Downloading webpage
# [youtube] YLbypZjHgSA: Downloading android player API JSON
# [info] YLbypZjHgSA: Downloading 1 format(s): 247+251
# [info] Writing video description to: Quotidian - 001 - Introduction! [YLbypZjHgSA].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YLbypZjHgSA
# [youtube] YLbypZjHgSA: Downloading webpage
# [youtube] YLbypZjHgSA: Downloading android player API JSON
# [info] YLbypZjHgSA: Downloading subtitles: en
# [info] YLbypZjHgSA: Downloading 1 format(s): 247+251
# [info] Writing video subtitles to: Quotidian - 001 - Introduction! [YLbypZjHgSA].en.vtt
# [download] Destination: Quotidian - 001 - Introduction! [YLbypZjHgSA].en.vtt
# [download] 100% of    6.56KiB in 00:00:00 at 44.31KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y2xjBJVzgME
# [youtube] y2xjBJVzgME: Downloading webpage
# [youtube] y2xjBJVzgME: Downloading android player API JSON
# [info] y2xjBJVzgME: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 002 - Something to live for! [y2xjBJVzgME].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y2xjBJVzgME
# [youtube] y2xjBJVzgME: Downloading webpage
# [youtube] y2xjBJVzgME: Downloading android player API JSON
# [youtube] y2xjBJVzgME: Downloading MPD manifest
# [info] y2xjBJVzgME: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Car9hV4gaN4
# [youtube] Car9hV4gaN4: Downloading webpage
# [youtube] Car9hV4gaN4: Downloading android player API JSON
# [info] Car9hV4gaN4: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 003 - Listening to Customers! [Car9hV4gaN4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Car9hV4gaN4
# [youtube] Car9hV4gaN4: Downloading webpage
# [youtube] Car9hV4gaN4: Downloading android player API JSON
# [info] Car9hV4gaN4: Downloading subtitles: en
# [info] Car9hV4gaN4: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 003 - Listening to Customers! [Car9hV4gaN4].en.vtt
# [download] Destination: Quotidian - 003 - Listening to Customers! [Car9hV4gaN4].en.vtt
# [download] 100% of    6.86KiB in 00:00:00 at 35.06KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Xtn_khIeXUo
# [youtube] Xtn_khIeXUo: Downloading webpage
# [youtube] Xtn_khIeXUo: Downloading android player API JSON
# [info] Xtn_khIeXUo: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 004 - Meaningful Metrics! [Xtn_khIeXUo].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Xtn_khIeXUo
# [youtube] Xtn_khIeXUo: Downloading webpage
# [youtube] Xtn_khIeXUo: Downloading android player API JSON
# [youtube] Xtn_khIeXUo: Downloading MPD manifest
# [info] Xtn_khIeXUo: Downloading subtitles: en
# [info] Xtn_khIeXUo: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 004 - Meaningful Metrics! [Xtn_khIeXUo].en.vtt
# [download] Destination: Quotidian - 004 - Meaningful Metrics! [Xtn_khIeXUo].en.vtt
# [download] 100% of    8.00KiB in 00:00:00 at 43.98KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1LK5vhqXfQM
# [youtube] 1LK5vhqXfQM: Downloading webpage
# [youtube] 1LK5vhqXfQM: Downloading android player API JSON
# [info] 1LK5vhqXfQM: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 005 - Strange Coincidences! [1LK5vhqXfQM].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1LK5vhqXfQM
# [youtube] 1LK5vhqXfQM: Downloading webpage
# [youtube] 1LK5vhqXfQM: Downloading android player API JSON
# [info] 1LK5vhqXfQM: Downloading subtitles: en
# [info] 1LK5vhqXfQM: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 005 - Strange Coincidences! [1LK5vhqXfQM].en.vtt
# [download] Destination: Quotidian - 005 - Strange Coincidences! [1LK5vhqXfQM].en.vtt
# [download] 100% of    6.26KiB in 00:00:00 at 30.84KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9ADacc4x79A
# [youtube] 9ADacc4x79A: Downloading webpage
# [youtube] 9ADacc4x79A: Downloading android player API JSON
# [info] 9ADacc4x79A: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 006 - Overcoming Stagefright! [9ADacc4x79A].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9ADacc4x79A
# [youtube] 9ADacc4x79A: Downloading webpage
# [youtube] 9ADacc4x79A: Downloading android player API JSON
# [youtube] 9ADacc4x79A: Downloading MPD manifest
# [info] 9ADacc4x79A: Downloading subtitles: en
# [info] 9ADacc4x79A: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 006 - Overcoming Stagefright! [9ADacc4x79A].en.vtt
# [download] Destination: Quotidian - 006 - Overcoming Stagefright! [9ADacc4x79A].en.vtt
# [download] 100% of    5.36KiB in 00:00:01 at 4.57KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y0ERXQScviY
# [youtube] y0ERXQScviY: Downloading webpage
# [youtube] y0ERXQScviY: Downloading android player API JSON
# [info] y0ERXQScviY: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 007 - Pay Attention! [y0ERXQScviY].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y0ERXQScviY
# [youtube] y0ERXQScviY: Downloading webpage
# [youtube] y0ERXQScviY: Downloading android player API JSON
# [youtube] y0ERXQScviY: Downloading MPD manifest
# [info] y0ERXQScviY: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uB7PnBRMHoM
# [youtube] uB7PnBRMHoM: Downloading webpage
# [youtube] uB7PnBRMHoM: Downloading android player API JSON
# [info] uB7PnBRMHoM: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 008 - Another Kinda Gorilla! [uB7PnBRMHoM].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uB7PnBRMHoM
# [youtube] uB7PnBRMHoM: Downloading webpage
# [youtube] uB7PnBRMHoM: Downloading android player API JSON
# [youtube] uB7PnBRMHoM: Downloading MPD manifest
# [info] uB7PnBRMHoM: Downloading subtitles: en
# [info] uB7PnBRMHoM: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 008 - Another Kinda Gorilla! [uB7PnBRMHoM].en.vtt
# [download] Destination: Quotidian - 008 - Another Kinda Gorilla! [uB7PnBRMHoM].en.vtt
# [download] 100% of    8.33KiB in 00:00:01 at 6.93KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RRRhhLz5uqc
# [youtube] RRRhhLz5uqc: Downloading webpage
# [youtube] RRRhhLz5uqc: Downloading android player API JSON
# [info] RRRhhLz5uqc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 009 - Six Honest Serving Men! [RRRhhLz5uqc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RRRhhLz5uqc
# [youtube] RRRhhLz5uqc: Downloading webpage
# [youtube] RRRhhLz5uqc: Downloading android player API JSON
# [youtube] RRRhhLz5uqc: Downloading MPD manifest
# [info] RRRhhLz5uqc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pYDB_AOATR8
# [youtube] pYDB_AOATR8: Downloading webpage
# [youtube] pYDB_AOATR8: Downloading android player API JSON
# [info] pYDB_AOATR8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 010 - Q and A for 001 to 009 [pYDB_AOATR8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pYDB_AOATR8
# [youtube] pYDB_AOATR8: Downloading webpage
# [youtube] pYDB_AOATR8: Downloading android player API JSON
# [info] pYDB_AOATR8: Downloading subtitles: en
# [info] pYDB_AOATR8: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 010 - Q and A for 001 to 009 [pYDB_AOATR8].en.vtt
# [download] Destination: Quotidian - 010 - Q and A for 001 to 009 [pYDB_AOATR8].en.vtt
# [download] 100% of   14.34KiB in 00:00:00 at 72.72KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KoBjonDInc0
# [youtube] KoBjonDInc0: Downloading webpage
# [youtube] KoBjonDInc0: Downloading android player API JSON
# [info] KoBjonDInc0: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 011- Wear Are We Going？ [KoBjonDInc0].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KoBjonDInc0
# [youtube] KoBjonDInc0: Downloading webpage
# [youtube] KoBjonDInc0: Downloading android player API JSON
# [info] KoBjonDInc0: Downloading subtitles: en
# [info] KoBjonDInc0: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 011- Wear Are We Going？ [KoBjonDInc0].en.vtt
# [download] Destination: Quotidian - 011- Wear Are We Going？ [KoBjonDInc0].en.vtt
# [download] 100% of    7.05KiB in 00:00:00 at 19.61KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bfNqTg5C1qQ
# [youtube] bfNqTg5C1qQ: Downloading webpage
# [youtube] bfNqTg5C1qQ: Downloading android player API JSON
# [info] bfNqTg5C1qQ: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 012 - Where The Puck？ [bfNqTg5C1qQ].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bfNqTg5C1qQ
# [youtube] bfNqTg5C1qQ: Downloading webpage
# [youtube] bfNqTg5C1qQ: Downloading android player API JSON
# [info] bfNqTg5C1qQ: Downloading subtitles: en
# [info] bfNqTg5C1qQ: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 012 - Where The Puck？ [bfNqTg5C1qQ].en.vtt
# [download] Destination: Quotidian - 012 - Where The Puck？ [bfNqTg5C1qQ].en.vtt
# [download] 100% of    7.38KiB in 00:00:01 at 5.67KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Zqv4lKaBHKE
# [youtube] Zqv4lKaBHKE: Downloading webpage
# [youtube] Zqv4lKaBHKE: Downloading android player API JSON
# [info] Zqv4lKaBHKE: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 013 - 12 + 1 = 13! [Zqv4lKaBHKE].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Zqv4lKaBHKE
# [youtube] Zqv4lKaBHKE: Downloading webpage
# [youtube] Zqv4lKaBHKE: Downloading android player API JSON
# [info] Zqv4lKaBHKE: Downloading subtitles: en
# [info] Zqv4lKaBHKE: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 013 - 12 + 1 = 13! [Zqv4lKaBHKE].en.vtt
# [download] Destination: Quotidian - 013 - 12 + 1 = 13! [Zqv4lKaBHKE].en.vtt
# [download] 100% of    8.82KiB in 00:00:00 at 11.26KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rBScvcx_Xnk
# [youtube] rBScvcx_Xnk: Downloading webpage
# [youtube] rBScvcx_Xnk: Downloading android player API JSON
# [info] rBScvcx_Xnk: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 014 - Balance The Ottoman! [rBScvcx_Xnk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rBScvcx_Xnk
# [youtube] rBScvcx_Xnk: Downloading webpage
# [youtube] rBScvcx_Xnk: Downloading android player API JSON
# [youtube] rBScvcx_Xnk: Downloading MPD manifest
# [info] rBScvcx_Xnk: Downloading subtitles: en
# [info] rBScvcx_Xnk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 014 - Balance The Ottoman! [rBScvcx_Xnk].en.vtt
# [download] Destination: Quotidian - 014 - Balance The Ottoman! [rBScvcx_Xnk].en.vtt
# [download] 100% of    8.39KiB in 00:00:00 at 16.46KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=exQQV5sMkWw
# [youtube] exQQV5sMkWw: Downloading webpage
# [youtube] exQQV5sMkWw: Downloading android player API JSON
# [info] exQQV5sMkWw: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 015 - The Robots Are Coming! [exQQV5sMkWw].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=exQQV5sMkWw
# [youtube] exQQV5sMkWw: Downloading webpage
# [youtube] exQQV5sMkWw: Downloading android player API JSON
# [youtube] exQQV5sMkWw: Downloading MPD manifest
# [info] exQQV5sMkWw: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-hQbAIfovtQ
# [youtube] -hQbAIfovtQ: Downloading webpage
# [youtube] -hQbAIfovtQ: Downloading android player API JSON
# [info] -hQbAIfovtQ: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 016 - Trust Is Key! [-hQbAIfovtQ].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-hQbAIfovtQ
# [youtube] -hQbAIfovtQ: Downloading webpage
# [youtube] -hQbAIfovtQ: Downloading android player API JSON
# [youtube] -hQbAIfovtQ: Downloading MPD manifest
# [info] -hQbAIfovtQ: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x5ZJk8pnah8
# [youtube] x5ZJk8pnah8: Downloading webpage
# [youtube] x5ZJk8pnah8: Downloading android player API JSON
# [info] x5ZJk8pnah8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 017 - Three Ways To Win! [x5ZJk8pnah8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x5ZJk8pnah8
# [youtube] x5ZJk8pnah8: Downloading webpage
# [youtube] x5ZJk8pnah8: Downloading android player API JSON
# [youtube] x5ZJk8pnah8: Downloading MPD manifest
# [info] x5ZJk8pnah8: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7nswfaKUHBw
# [youtube] 7nswfaKUHBw: Downloading webpage
# [youtube] 7nswfaKUHBw: Downloading android player API JSON
# [info] 7nswfaKUHBw: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 018 - The Circle of Knowledge [7nswfaKUHBw].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7nswfaKUHBw
# [youtube] 7nswfaKUHBw: Downloading webpage
# [youtube] 7nswfaKUHBw: Downloading android player API JSON
# [info] 7nswfaKUHBw: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z5m3ewyI33s
# [youtube] z5m3ewyI33s: Downloading webpage
# [youtube] z5m3ewyI33s: Downloading android player API JSON
# [info] z5m3ewyI33s: Downloading 1 format(s): 248+251
# [info] Writing video description to: Quotidian - 019 - Learn Sideways! [z5m3ewyI33s].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z5m3ewyI33s
# [youtube] z5m3ewyI33s: Downloading webpage
# [youtube] z5m3ewyI33s: Downloading android player API JSON
# [info] z5m3ewyI33s: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1YeEhKZ2Bas
# [youtube] 1YeEhKZ2Bas: Downloading webpage
# [youtube] 1YeEhKZ2Bas: Downloading android player API JSON
# [info] 1YeEhKZ2Bas: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 020 - Q and A for 011 to 019 [1YeEhKZ2Bas].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1YeEhKZ2Bas
# [youtube] 1YeEhKZ2Bas: Downloading webpage
# [youtube] 1YeEhKZ2Bas: Downloading android player API JSON
# [info] 1YeEhKZ2Bas: Downloading subtitles: en
# [info] 1YeEhKZ2Bas: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 020 - Q and A for 011 to 019 [1YeEhKZ2Bas].en.vtt
# [download] Destination: Quotidian - 020 - Q and A for 011 to 019 [1YeEhKZ2Bas].en.vtt
# [download] 100% of   12.28KiB in 00:00:00 at 25.69KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GyzGSh7x6iA
# [youtube] GyzGSh7x6iA: Downloading webpage
# [youtube] GyzGSh7x6iA: Downloading android player API JSON
# [info] GyzGSh7x6iA: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 021 - In Between! [GyzGSh7x6iA].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GyzGSh7x6iA
# [youtube] GyzGSh7x6iA: Downloading webpage
# [youtube] GyzGSh7x6iA: Downloading android player API JSON
# [youtube] GyzGSh7x6iA: Downloading MPD manifest
# [info] GyzGSh7x6iA: Downloading subtitles: en
# [info] GyzGSh7x6iA: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 021 - In Between! [GyzGSh7x6iA].en.vtt
# [download] Destination: Quotidian - 021 - In Between! [GyzGSh7x6iA].en.vtt
# [download] 100% of    8.25KiB in 00:00:01 at 5.26KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OhJAy0sOA0w
# [youtube] OhJAy0sOA0w: Downloading webpage
# [youtube] OhJAy0sOA0w: Downloading android player API JSON
# [info] OhJAy0sOA0w: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 022 - The Long Tail [OhJAy0sOA0w].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OhJAy0sOA0w
# [youtube] OhJAy0sOA0w: Downloading webpage
# [youtube] OhJAy0sOA0w: Downloading android player API JSON
# [info] OhJAy0sOA0w: Downloading subtitles: en
# [info] OhJAy0sOA0w: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 022 - The Long Tail [OhJAy0sOA0w].en.vtt
# [download] Destination: Quotidian - 022 - The Long Tail [OhJAy0sOA0w].en.vtt
# [download] 100% of   10.09KiB in 00:00:00 at 36.79KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iKghLFLaoF4
# [youtube] iKghLFLaoF4: Downloading webpage
# [youtube] iKghLFLaoF4: Downloading android player API JSON
# [info] iKghLFLaoF4: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 023 - The Opposite of Love [iKghLFLaoF4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iKghLFLaoF4
# [youtube] iKghLFLaoF4: Downloading webpage
# [youtube] iKghLFLaoF4: Downloading android player API JSON
# [youtube] iKghLFLaoF4: Downloading MPD manifest
# [info] iKghLFLaoF4: Downloading subtitles: en
# [info] iKghLFLaoF4: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 023 - The Opposite of Love [iKghLFLaoF4].en.vtt
# [download] Destination: Quotidian - 023 - The Opposite of Love [iKghLFLaoF4].en.vtt
# [download] 100% of    9.23KiB in 00:00:00 at 30.78KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hfcncSnHKis
# [youtube] hfcncSnHKis: Downloading webpage
# [youtube] hfcncSnHKis: Downloading android player API JSON
# [info] hfcncSnHKis: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 024 - Leave Silver, Grab Gold! [hfcncSnHKis].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hfcncSnHKis
# [youtube] hfcncSnHKis: Downloading webpage
# [youtube] hfcncSnHKis: Downloading android player API JSON
# [info] hfcncSnHKis: Downloading subtitles: en
# [info] hfcncSnHKis: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Quotidian - 024 - Leave Silver, Grab Gold! [hfcncSnHKis].en.vtt
# [download] Destination: Quotidian - 024 - Leave Silver, Grab Gold! [hfcncSnHKis].en.vtt
# [download] 100% of    5.72KiB in 00:00:00 at 15.56KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FRTxgmr4TKQ
# [youtube] FRTxgmr4TKQ: Downloading webpage
# [youtube] FRTxgmr4TKQ: Downloading android player API JSON
# [info] FRTxgmr4TKQ: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 025 - A Thousand Sparks [FRTxgmr4TKQ].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FRTxgmr4TKQ
# [youtube] FRTxgmr4TKQ: Downloading webpage
# [youtube] FRTxgmr4TKQ: Downloading android player API JSON
# [youtube] FRTxgmr4TKQ: Downloading MPD manifest
# [info] FRTxgmr4TKQ: Downloading subtitles: en
# [info] FRTxgmr4TKQ: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 025 - A Thousand Sparks [FRTxgmr4TKQ].en.vtt
# [download] Destination: Quotidian - 025 - A Thousand Sparks [FRTxgmr4TKQ].en.vtt
# [download] 100% of    9.51KiB in 00:00:00 at 28.79KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zd1Y1iKiFDg
# [youtube] zd1Y1iKiFDg: Downloading webpage
# [youtube] zd1Y1iKiFDg: Downloading android player API JSON
# [info] zd1Y1iKiFDg: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 026 - Plan for Slack [zd1Y1iKiFDg].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zd1Y1iKiFDg
# [youtube] zd1Y1iKiFDg: Downloading webpage
# [youtube] zd1Y1iKiFDg: Downloading android player API JSON
# [youtube] zd1Y1iKiFDg: Downloading MPD manifest
# [info] zd1Y1iKiFDg: Downloading subtitles: en
# [info] zd1Y1iKiFDg: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 026 - Plan for Slack [zd1Y1iKiFDg].en.vtt
# [download] Destination: Quotidian - 026 - Plan for Slack [zd1Y1iKiFDg].en.vtt
# [download] 100% of    7.15KiB in 00:00:00 at 40.46KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VrPOfVqvZ_Q
# [youtube] VrPOfVqvZ_Q: Downloading webpage
# [youtube] VrPOfVqvZ_Q: Downloading android player API JSON
# [info] VrPOfVqvZ_Q: Downloading 1 format(s): 248+251
# [info] Writing video description to: Quotidian - 027 - An Achiever! [VrPOfVqvZ_Q].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VrPOfVqvZ_Q
# [youtube] VrPOfVqvZ_Q: Downloading webpage
# [youtube] VrPOfVqvZ_Q: Downloading android player API JSON
# [info] VrPOfVqvZ_Q: Downloading subtitles: en
# [info] VrPOfVqvZ_Q: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 027 - An Achiever! [VrPOfVqvZ_Q].en.vtt
# [download] Destination: Quotidian - 027 - An Achiever! [VrPOfVqvZ_Q].en.vtt
# [download] 100% of    8.39KiB in 00:00:00 at 42.68KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BqFrJZZZTsk
# [youtube] BqFrJZZZTsk: Downloading webpage
# [youtube] BqFrJZZZTsk: Downloading android player API JSON
# [info] BqFrJZZZTsk: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 028 - Scratch an Itch! [BqFrJZZZTsk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BqFrJZZZTsk
# [youtube] BqFrJZZZTsk: Downloading webpage
# [youtube] BqFrJZZZTsk: Downloading android player API JSON
# [youtube] BqFrJZZZTsk: Downloading MPD manifest
# [info] BqFrJZZZTsk: Downloading subtitles: en
# [info] BqFrJZZZTsk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 028 - Scratch an Itch! [BqFrJZZZTsk].en.vtt
# [download] Destination: Quotidian - 028 - Scratch an Itch! [BqFrJZZZTsk].en.vtt
# [download] 100% of    7.25KiB in 00:00:00 at 24.36KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QGB_0JnlKfs
# [youtube] QGB_0JnlKfs: Downloading webpage
# [youtube] QGB_0JnlKfs: Downloading android player API JSON
# [info] QGB_0JnlKfs: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 029 - The Man In The Arena! [QGB_0JnlKfs].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QGB_0JnlKfs
# [youtube] QGB_0JnlKfs: Downloading webpage
# [youtube] QGB_0JnlKfs: Downloading android player API JSON
# [youtube] QGB_0JnlKfs: Downloading MPD manifest
# [info] QGB_0JnlKfs: Downloading subtitles: en
# [info] QGB_0JnlKfs: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Quotidian - 029 - The Man In The Arena! [QGB_0JnlKfs].en.vtt
# [download] Destination: Quotidian - 029 - The Man In The Arena! [QGB_0JnlKfs].en.vtt
# [download] 100% of    7.47KiB in 00:00:00 at 19.10KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZttFss21q5Q
# [youtube] ZttFss21q5Q: Downloading webpage
# [youtube] ZttFss21q5Q: Downloading android player API JSON
# [info] ZttFss21q5Q: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 030 - Q and A for 021 to 029 [ZttFss21q5Q].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZttFss21q5Q
# [youtube] ZttFss21q5Q: Downloading webpage
# [youtube] ZttFss21q5Q: Downloading android player API JSON
# [youtube] ZttFss21q5Q: Downloading MPD manifest
# [info] ZttFss21q5Q: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rIv2msdC0GM
# [youtube] rIv2msdC0GM: Downloading webpage
# [youtube] rIv2msdC0GM: Downloading android player API JSON
# [info] rIv2msdC0GM: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 031 - Why Ask Why？ [rIv2msdC0GM].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rIv2msdC0GM
# [youtube] rIv2msdC0GM: Downloading webpage
# [youtube] rIv2msdC0GM: Downloading android player API JSON
# [youtube] rIv2msdC0GM: Downloading MPD manifest
# [info] rIv2msdC0GM: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QH5LYYjDgyc
# [youtube] QH5LYYjDgyc: Downloading webpage
# [youtube] QH5LYYjDgyc: Downloading android player API JSON
# [info] QH5LYYjDgyc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 032 - Look, Don't See! [QH5LYYjDgyc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QH5LYYjDgyc
# [youtube] QH5LYYjDgyc: Downloading webpage
# [youtube] QH5LYYjDgyc: Downloading android player API JSON
# [youtube] QH5LYYjDgyc: Downloading MPD manifest
# [info] QH5LYYjDgyc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5qB2_bcjkLk
# [youtube] 5qB2_bcjkLk: Downloading webpage
# [youtube] 5qB2_bcjkLk: Downloading android player API JSON
# [info] 5qB2_bcjkLk: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 033 - Distracted Minds! [5qB2_bcjkLk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5qB2_bcjkLk
# [youtube] 5qB2_bcjkLk: Downloading webpage
# [youtube] 5qB2_bcjkLk: Downloading android player API JSON
# [info] 5qB2_bcjkLk: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OkwhNSFohBw
# [youtube] OkwhNSFohBw: Downloading webpage
# [youtube] OkwhNSFohBw: Downloading android player API JSON
# [info] OkwhNSFohBw: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 034 - 800 Lifetimes! [OkwhNSFohBw].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OkwhNSFohBw
# [youtube] OkwhNSFohBw: Downloading webpage
# [youtube] OkwhNSFohBw: Downloading android player API JSON
# [info] OkwhNSFohBw: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PQ8o03jaG4c
# [youtube] PQ8o03jaG4c: Downloading webpage
# [youtube] PQ8o03jaG4c: Downloading android player API JSON
# [info] PQ8o03jaG4c: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 035 - This Too Shall... [PQ8o03jaG4c].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PQ8o03jaG4c
# [youtube] PQ8o03jaG4c: Downloading webpage
# [youtube] PQ8o03jaG4c: Downloading android player API JSON
# [youtube] PQ8o03jaG4c: Downloading MPD manifest
# [info] PQ8o03jaG4c: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=g8H5PO03rKc
# [youtube] g8H5PO03rKc: Downloading webpage
# [youtube] g8H5PO03rKc: Downloading android player API JSON
# [info] g8H5PO03rKc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 036 - Gone in 60 Seconds! [g8H5PO03rKc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=g8H5PO03rKc
# [youtube] g8H5PO03rKc: Downloading webpage
# [youtube] g8H5PO03rKc: Downloading android player API JSON
# [youtube] g8H5PO03rKc: Downloading MPD manifest
# [info] g8H5PO03rKc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MlKYjbYq9Ow
# [youtube] MlKYjbYq9Ow: Downloading webpage
# [youtube] MlKYjbYq9Ow: Downloading android player API JSON
# [info] MlKYjbYq9Ow: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 037 - Best (？) Wishes! [MlKYjbYq9Ow].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MlKYjbYq9Ow
# [youtube] MlKYjbYq9Ow: Downloading webpage
# [youtube] MlKYjbYq9Ow: Downloading android player API JSON
# [info] MlKYjbYq9Ow: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vcarJKOr5HA
# [youtube] vcarJKOr5HA: Downloading webpage
# [youtube] vcarJKOr5HA: Downloading android player API JSON
# [info] vcarJKOr5HA: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 038 - The Ladder's Steps! [vcarJKOr5HA].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vcarJKOr5HA
# [youtube] vcarJKOr5HA: Downloading webpage
# [youtube] vcarJKOr5HA: Downloading android player API JSON
# [youtube] vcarJKOr5HA: Downloading MPD manifest
# [info] vcarJKOr5HA: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ohAQdQ791d8
# [youtube] ohAQdQ791d8: Downloading webpage
# [youtube] ohAQdQ791d8: Downloading android player API JSON
# [info] ohAQdQ791d8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 039 - Chasm Crossing! [ohAQdQ791d8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ohAQdQ791d8
# [youtube] ohAQdQ791d8: Downloading webpage
# [youtube] ohAQdQ791d8: Downloading android player API JSON
# [youtube] ohAQdQ791d8: Downloading MPD manifest
# [info] ohAQdQ791d8: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LWtn1Ugiwqc
# [youtube] LWtn1Ugiwqc: Downloading webpage
# [youtube] LWtn1Ugiwqc: Downloading android player API JSON
# [info] LWtn1Ugiwqc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 040 - Q and A for 031 to 039 [LWtn1Ugiwqc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LWtn1Ugiwqc
# [youtube] LWtn1Ugiwqc: Downloading webpage
# [youtube] LWtn1Ugiwqc: Downloading android player API JSON
# [youtube] LWtn1Ugiwqc: Downloading MPD manifest
# [info] LWtn1Ugiwqc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZgoznZPU8VY
# [youtube] ZgoznZPU8VY: Downloading webpage
# [youtube] ZgoznZPU8VY: Downloading android player API JSON
# [info] ZgoznZPU8VY: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 041 - The Power Of Words! [ZgoznZPU8VY].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZgoznZPU8VY
# [youtube] ZgoznZPU8VY: Downloading webpage
# [youtube] ZgoznZPU8VY: Downloading android player API JSON
# [info] ZgoznZPU8VY: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TiFr59DpfkU
# [youtube] TiFr59DpfkU: Downloading webpage
# [youtube] TiFr59DpfkU: Downloading android player API JSON
# [info] TiFr59DpfkU: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 042 - The Last Question! [TiFr59DpfkU].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TiFr59DpfkU
# [youtube] TiFr59DpfkU: Downloading webpage
# [youtube] TiFr59DpfkU: Downloading android player API JSON
# [youtube] TiFr59DpfkU: Downloading MPD manifest
# [info] TiFr59DpfkU: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Rno54STeHxU
# [youtube] Rno54STeHxU: Downloading webpage
# [youtube] Rno54STeHxU: Downloading android player API JSON
# [info] Rno54STeHxU: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 043 - The Last Answer! [Rno54STeHxU].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Rno54STeHxU
# [youtube] Rno54STeHxU: Downloading webpage
# [youtube] Rno54STeHxU: Downloading android player API JSON
# [info] Rno54STeHxU: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NW-CsC1GxW8
# [youtube] NW-CsC1GxW8: Downloading webpage
# [youtube] NW-CsC1GxW8: Downloading android player API JSON
# [info] NW-CsC1GxW8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 044 - Micromanagement [NW-CsC1GxW8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NW-CsC1GxW8
# [youtube] NW-CsC1GxW8: Downloading webpage
# [youtube] NW-CsC1GxW8: Downloading android player API JSON
# [youtube] NW-CsC1GxW8: Downloading MPD manifest
# [info] NW-CsC1GxW8: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tEKj-0Rloz4
# [youtube] tEKj-0Rloz4: Downloading webpage
# [youtube] tEKj-0Rloz4: Downloading android player API JSON
# [info] tEKj-0Rloz4: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 045 - Steal Well! [tEKj-0Rloz4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tEKj-0Rloz4
# [youtube] tEKj-0Rloz4: Downloading webpage
# [youtube] tEKj-0Rloz4: Downloading android player API JSON
# [info] tEKj-0Rloz4: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=M55epZrE9s0
# [youtube] M55epZrE9s0: Downloading webpage
# [youtube] M55epZrE9s0: Downloading android player API JSON
# [info] M55epZrE9s0: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 046 - The Novice! [M55epZrE9s0].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=M55epZrE9s0
# [youtube] M55epZrE9s0: Downloading webpage
# [youtube] M55epZrE9s0: Downloading android player API JSON
# [info] M55epZrE9s0: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fTY7ejq7MN0
# [youtube] fTY7ejq7MN0: Downloading webpage
# [youtube] fTY7ejq7MN0: Downloading android player API JSON
# [info] fTY7ejq7MN0: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 047 - Breadth Or Depth？ [fTY7ejq7MN0].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fTY7ejq7MN0
# [youtube] fTY7ejq7MN0: Downloading webpage
# [youtube] fTY7ejq7MN0: Downloading android player API JSON
# [info] fTY7ejq7MN0: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mXYwt8FgUbI
# [youtube] mXYwt8FgUbI: Downloading webpage
# [youtube] mXYwt8FgUbI: Downloading android player API JSON
# [info] mXYwt8FgUbI: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 048 - The Learning Bowl [mXYwt8FgUbI].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mXYwt8FgUbI
# [youtube] mXYwt8FgUbI: Downloading webpage
# [youtube] mXYwt8FgUbI: Downloading android player API JSON
# [youtube] mXYwt8FgUbI: Downloading MPD manifest
# [info] mXYwt8FgUbI: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cZpP8SjCzXU
# [youtube] cZpP8SjCzXU: Downloading webpage
# [youtube] cZpP8SjCzXU: Downloading android player API JSON
# [info] cZpP8SjCzXU: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 049 - Why Do We Buy？ [cZpP8SjCzXU].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cZpP8SjCzXU
# [youtube] cZpP8SjCzXU: Downloading webpage
# [youtube] cZpP8SjCzXU: Downloading android player API JSON
# [youtube] cZpP8SjCzXU: Downloading MPD manifest
# [info] cZpP8SjCzXU: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Oilx-83lob8
# [youtube] Oilx-83lob8: Downloading webpage
# [youtube] Oilx-83lob8: Downloading android player API JSON
# [info] Oilx-83lob8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 050 - Q and A for 041 to 049 [Oilx-83lob8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Oilx-83lob8
# [youtube] Oilx-83lob8: Downloading webpage
# [youtube] Oilx-83lob8: Downloading android player API JSON
# [youtube] Oilx-83lob8: Downloading MPD manifest
# [info] Oilx-83lob8: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=k1WuVNQ3_VU
# [youtube] k1WuVNQ3_VU: Downloading webpage
# [youtube] k1WuVNQ3_VU: Downloading android player API JSON
# [info] k1WuVNQ3_VU: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 051 - Late Delivery [k1WuVNQ3_VU].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=k1WuVNQ3_VU
# [youtube] k1WuVNQ3_VU: Downloading webpage
# [youtube] k1WuVNQ3_VU: Downloading android player API JSON
# [info] k1WuVNQ3_VU: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6xn2rUtkGCI
# [youtube] 6xn2rUtkGCI: Downloading webpage
# WARNING: [youtube] Unable to download webpage: The read operation timed out
# [youtube] 6xn2rUtkGCI: Downloading android player API JSON
# [youtube] 6xn2rUtkGCI: Downloading iframe API JS
# [youtube] 6xn2rUtkGCI: Downloading player 36754c51
# [youtube] 6xn2rUtkGCI: Downloading web player API JSON
# [youtube] 6xn2rUtkGCI: Downloading initial data API JSON
# [info] 6xn2rUtkGCI: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 052 - Four Failures [6xn2rUtkGCI].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6xn2rUtkGCI
# [youtube] 6xn2rUtkGCI: Downloading webpage
# [youtube] 6xn2rUtkGCI: Downloading android player API JSON
# WARNING: [youtube] 6xn2rUtkGCI: nsig extraction failed: You may experience throttling for some formats
#          Install PhantomJS to workaround the issue. Please download it from https://phantomjs.org/download.html
#          n = jOy1S8MkPdUnmB ; player = https://www.youtube.com/s/player/6f20102c/player_ias.vflset/en_US/base.js
# [info] 6xn2rUtkGCI: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VStrvxwHKwc
# [youtube] VStrvxwHKwc: Downloading webpage
# [youtube] VStrvxwHKwc: Downloading android player API JSON
# [info] VStrvxwHKwc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 053 - Beautifully Buggy？ [VStrvxwHKwc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VStrvxwHKwc
# [youtube] VStrvxwHKwc: Downloading webpage
# [youtube] VStrvxwHKwc: Downloading android player API JSON
# [youtube] VStrvxwHKwc: Downloading MPD manifest
# [info] VStrvxwHKwc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XnUK6colGg4
# [youtube] XnUK6colGg4: Downloading webpage
# [youtube] XnUK6colGg4: Downloading android player API JSON
# [info] XnUK6colGg4: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 054 - Focus On Strengths! [XnUK6colGg4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XnUK6colGg4
# [youtube] XnUK6colGg4: Downloading webpage
# [youtube] XnUK6colGg4: Downloading android player API JSON
# [youtube] XnUK6colGg4: Downloading MPD manifest
# [info] XnUK6colGg4: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l1Zvrlw3nCE
# [youtube] l1Zvrlw3nCE: Downloading webpage
# [youtube] l1Zvrlw3nCE: Downloading android player API JSON
# [info] l1Zvrlw3nCE: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 055 - The Learner Mindset! [l1Zvrlw3nCE].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l1Zvrlw3nCE
# [youtube] l1Zvrlw3nCE: Downloading webpage
# [youtube] l1Zvrlw3nCE: Downloading android player API JSON
# [youtube] l1Zvrlw3nCE: Downloading MPD manifest
# [info] l1Zvrlw3nCE: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Vq_Kb2kpaCI
# [youtube] Vq_Kb2kpaCI: Downloading webpage
# [youtube] Vq_Kb2kpaCI: Downloading android player API JSON
# [info] Vq_Kb2kpaCI: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 056 - Running Races! [Vq_Kb2kpaCI].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Vq_Kb2kpaCI
# [youtube] Vq_Kb2kpaCI: Downloading webpage
# [youtube] Vq_Kb2kpaCI: Downloading android player API JSON
# [youtube] Vq_Kb2kpaCI: Downloading MPD manifest
# [info] Vq_Kb2kpaCI: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6ss-5fm4RNU
# [youtube] 6ss-5fm4RNU: Downloading webpage
# [youtube] 6ss-5fm4RNU: Downloading android player API JSON
# [info] 6ss-5fm4RNU: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 057 - Future Tense! [6ss-5fm4RNU].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6ss-5fm4RNU
# [youtube] 6ss-5fm4RNU: Downloading webpage
# [youtube] 6ss-5fm4RNU: Downloading android player API JSON
# [info] 6ss-5fm4RNU: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e_BkzYx-B8s
# [youtube] e_BkzYx-B8s: Downloading webpage
# [youtube] e_BkzYx-B8s: Downloading android player API JSON
# WARNING: [youtube] e_BkzYx-B8s: nsig extraction failed: You may experience throttling for some formats
#          Install PhantomJS to workaround the issue. Please download it from https://phantomjs.org/download.html
#          n = vvfybnocB4BMdQ ; player = https://www.youtube.com/s/player/6f20102c/player_ias.vflset/en_US/base.js
# [info] e_BkzYx-B8s: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 058 - Think Different! [e_BkzYx-B8s].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e_BkzYx-B8s
# [youtube] e_BkzYx-B8s: Downloading webpage
# [youtube] e_BkzYx-B8s: Downloading android player API JSON
# [info] e_BkzYx-B8s: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rIa3kagmCGI
# [youtube] rIa3kagmCGI: Downloading webpage
# [youtube] rIa3kagmCGI: Downloading android player API JSON
# [info] rIa3kagmCGI: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 059 - Lizard Brain Speaks! [rIa3kagmCGI].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rIa3kagmCGI
# [youtube] rIa3kagmCGI: Downloading webpage
# [youtube] rIa3kagmCGI: Downloading android player API JSON
# [youtube] rIa3kagmCGI: Downloading MPD manifest
# [info] rIa3kagmCGI: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BRMnSMrH-K4
# [youtube] BRMnSMrH-K4: Downloading webpage
# [youtube] BRMnSMrH-K4: Downloading android player API JSON
# [info] BRMnSMrH-K4: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 060 - Q and A for 051 to 059 [BRMnSMrH-K4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BRMnSMrH-K4
# [youtube] BRMnSMrH-K4: Downloading webpage
# [youtube] BRMnSMrH-K4: Downloading android player API JSON
# [info] BRMnSMrH-K4: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uYtR7yVJ1ng
# [youtube] uYtR7yVJ1ng: Downloading webpage
# [youtube] uYtR7yVJ1ng: Downloading android player API JSON
# [info] uYtR7yVJ1ng: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 061 - Which Isaac？ [uYtR7yVJ1ng].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uYtR7yVJ1ng
# [youtube] uYtR7yVJ1ng: Downloading webpage
# [youtube] uYtR7yVJ1ng: Downloading android player API JSON
# [youtube] uYtR7yVJ1ng: Downloading MPD manifest
# [info] uYtR7yVJ1ng: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OyFxXt1dgew
# [youtube] OyFxXt1dgew: Downloading webpage
# [youtube] OyFxXt1dgew: Downloading android player API JSON
# [info] OyFxXt1dgew: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 062 - Four Circles! [OyFxXt1dgew].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OyFxXt1dgew
# [youtube] OyFxXt1dgew: Downloading webpage
# [youtube] OyFxXt1dgew: Downloading android player API JSON
# [info] OyFxXt1dgew: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0IM06vGrteE
# [youtube] 0IM06vGrteE: Downloading webpage
# [youtube] 0IM06vGrteE: Downloading android player API JSON
# [info] 0IM06vGrteE: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 063 - Retire Often! [0IM06vGrteE].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0IM06vGrteE
# [youtube] 0IM06vGrteE: Downloading webpage
# [youtube] 0IM06vGrteE: Downloading android player API JSON
# WARNING: [youtube] 0IM06vGrteE: nsig extraction failed: You may experience throttling for some formats
#          Install PhantomJS to workaround the issue. Please download it from https://phantomjs.org/download.html
#          n = h9oWI4uud9ziWm ; player = https://www.youtube.com/s/player/6f20102c/player_ias.vflset/en_US/base.js
# [info] 0IM06vGrteE: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nxsfSLIC16o
# [youtube] nxsfSLIC16o: Downloading webpage
# [youtube] nxsfSLIC16o: Downloading android player API JSON
# [info] nxsfSLIC16o: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 064 - Arjuna! Arjuna!! [nxsfSLIC16o].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nxsfSLIC16o
# [youtube] nxsfSLIC16o: Downloading webpage
# [youtube] nxsfSLIC16o: Downloading android player API JSON
# [info] nxsfSLIC16o: Downloading 1 format(s): 137+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5__Bi82jfyc
# [youtube] 5__Bi82jfyc: Downloading webpage
# [youtube] 5__Bi82jfyc: Downloading android player API JSON
# [info] 5__Bi82jfyc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 065 - Arjuna's Arrow! [5__Bi82jfyc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5__Bi82jfyc
# [youtube] 5__Bi82jfyc: Downloading webpage
# [youtube] 5__Bi82jfyc: Downloading android player API JSON
# [youtube] 5__Bi82jfyc: Downloading MPD manifest
# [info] 5__Bi82jfyc: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x5M1ZTRS3e0
# [youtube] x5M1ZTRS3e0: Downloading webpage
# [youtube] x5M1ZTRS3e0: Downloading android player API JSON
# [info] x5M1ZTRS3e0: Downloading 1 format(s): 137+251
# [info] Writing video description to: Quotidian - 066 - Newton's Help! [x5M1ZTRS3e0].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x5M1ZTRS3e0
# [youtube] x5M1ZTRS3e0: Downloading webpage
# [youtube] x5M1ZTRS3e0: Downloading android player API JSON
# [youtube] x5M1ZTRS3e0: Downloading MPD manifest
# [info] x5M1ZTRS3e0: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=d3ODOhNFGUU
# [youtube] d3ODOhNFGUU: Downloading webpage
# [youtube] d3ODOhNFGUU: Downloading android player API JSON
# [info] d3ODOhNFGUU: Downloading 1 format(s): 137+251
# ...
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LnSBMe8A-Xk
# [youtube] LnSBMe8A-Xk: Downloading webpage
# [youtube] LnSBMe8A-Xk: Downloading android player API JSON
# [info] LnSBMe8A-Xk: Downloading 1 format(s): 248+251
# [info] Writing video description to: Market It! - Quotidian - 446 [LnSBMe8A-Xk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LnSBMe8A-Xk
# [youtube] LnSBMe8A-Xk: Downloading webpage
# [youtube] LnSBMe8A-Xk: Downloading android player API JSON
# [info] LnSBMe8A-Xk: Downloading subtitles: en
# [info] LnSBMe8A-Xk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Market It! - Quotidian - 446 [LnSBMe8A-Xk].en.vtt
# [download] Destination: Market It! - Quotidian - 446 [LnSBMe8A-Xk].en.vtt
# [download] 100% of   18.70KiB in 00:00:01 at 12.33KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UvpSLy94hYM
# [youtube] UvpSLy94hYM: Downloading webpage
# [youtube] UvpSLy94hYM: Downloading android player API JSON
# [info] UvpSLy94hYM: Downloading 1 format(s): 248+251
# [info] Writing video description to: Acknowledge! - Quotidian - 447 [UvpSLy94hYM].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UvpSLy94hYM
# [youtube] UvpSLy94hYM: Downloading webpage
# [youtube] UvpSLy94hYM: Downloading android player API JSON
# [info] UvpSLy94hYM: Downloading subtitles: en
# [info] UvpSLy94hYM: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Acknowledge! - Quotidian - 447 [UvpSLy94hYM].en.vtt
# [download] Destination: Acknowledge! - Quotidian - 447 [UvpSLy94hYM].en.vtt
# [download] 100% of   19.02KiB in 00:00:00 at 35.08KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WmvT3qXoHbM
# [youtube] WmvT3qXoHbM: Downloading webpage
# [youtube] WmvT3qXoHbM: Downloading android player API JSON
# [info] WmvT3qXoHbM: Downloading 1 format(s): 248+251
# [info] Writing video description to: Assessing Asses! - Quotidian - 448 [WmvT3qXoHbM].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WmvT3qXoHbM
# [youtube] WmvT3qXoHbM: Downloading webpage
# [youtube] WmvT3qXoHbM: Downloading android player API JSON
# [info] WmvT3qXoHbM: Downloading subtitles: en
# [info] WmvT3qXoHbM: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Assessing Asses! - Quotidian - 448 [WmvT3qXoHbM].en.vtt
# [download] Destination: Assessing Asses! - Quotidian - 448 [WmvT3qXoHbM].en.vtt
# [download] 100% of   19.33KiB in 00:00:00 at 62.29KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uZX9fpL2qC8
# [youtube] uZX9fpL2qC8: Downloading webpage
# [youtube] uZX9fpL2qC8: Downloading android player API JSON
# [info] uZX9fpL2qC8: Downloading 1 format(s): 248+251
# [info] Writing video description to: Stages Of Love! - Quotidian - 449 [uZX9fpL2qC8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uZX9fpL2qC8
# [youtube] uZX9fpL2qC8: Downloading webpage
# [youtube] uZX9fpL2qC8: Downloading android player API JSON
# [info] uZX9fpL2qC8: Downloading subtitles: en
# [info] uZX9fpL2qC8: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Stages Of Love! - Quotidian - 449 [uZX9fpL2qC8].en.vtt
# [download] Destination: Stages Of Love! - Quotidian - 449 [uZX9fpL2qC8].en.vtt
# [download] 100% of   21.98KiB in 00:00:00 at 26.91KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=H9gBFTcqFDE
# [youtube] H9gBFTcqFDE: Downloading webpage
# [youtube] H9gBFTcqFDE: Downloading android player API JSON
# [info] H9gBFTcqFDE: Downloading 1 format(s): 248+251
# [info] Writing video description to: Q and A for 441 to 449— Quotidian — 450 [H9gBFTcqFDE].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=H9gBFTcqFDE
# [youtube] H9gBFTcqFDE: Downloading webpage
# [youtube] H9gBFTcqFDE: Downloading android player API JSON
# [info] H9gBFTcqFDE: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EWZuJlJ2y00
# [youtube] EWZuJlJ2y00: Downloading webpage
# [youtube] EWZuJlJ2y00: Downloading android player API JSON
# [info] EWZuJlJ2y00: Downloading 1 format(s): 137+251
# [info] Writing video description to: Sins You’re Learning! - Quotidian - 451 [EWZuJlJ2y00].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EWZuJlJ2y00
# [youtube] EWZuJlJ2y00: Downloading webpage
# [youtube] EWZuJlJ2y00: Downloading android player API JSON
# [info] EWZuJlJ2y00: Downloading subtitles: en
# [info] EWZuJlJ2y00: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Sins You’re Learning! - Quotidian - 451 [EWZuJlJ2y00].en.vtt
# [download] Destination: Sins You’re Learning! - Quotidian - 451 [EWZuJlJ2y00].en.vtt
# [download] 100% of   21.83KiB in 00:00:00 at 51.87KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=clt5dlW5vOc
# [youtube] clt5dlW5vOc: Downloading webpage
# [youtube] clt5dlW5vOc: Downloading android player API JSON
# [info] clt5dlW5vOc: Downloading 1 format(s): 137+251
# [info] Writing video description to: Feedback Fundas! - Quotidian - 452 [clt5dlW5vOc].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=clt5dlW5vOc
# [youtube] clt5dlW5vOc: Downloading webpage
# [youtube] clt5dlW5vOc: Downloading android player API JSON
# [info] clt5dlW5vOc: Downloading subtitles: en
# [info] clt5dlW5vOc: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Feedback Fundas! - Quotidian - 452 [clt5dlW5vOc].en.vtt
# [download] Destination: Feedback Fundas! - Quotidian - 452 [clt5dlW5vOc].en.vtt
# [download] 100% of   21.38KiB in 00:00:00 at 50.13KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GA3AizKpq2g
# [youtube] GA3AizKpq2g: Downloading webpage
# [youtube] GA3AizKpq2g: Downloading android player API JSON
# [info] GA3AizKpq2g: Downloading 1 format(s): 137+251
# [info] Writing video description to: Driverless! - Quotidian - 453 [GA3AizKpq2g].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GA3AizKpq2g
# [youtube] GA3AizKpq2g: Downloading webpage
# [youtube] GA3AizKpq2g: Downloading android player API JSON
# [info] GA3AizKpq2g: Downloading subtitles: en
# [info] GA3AizKpq2g: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Driverless! - Quotidian - 453 [GA3AizKpq2g].en.vtt
# [download] Destination: Driverless! - Quotidian - 453 [GA3AizKpq2g].en.vtt
# [download] 100% of   21.96KiB in 00:00:00 at 67.79KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=g_MxMW61Mbk
# [youtube] g_MxMW61Mbk: Downloading webpage
# [youtube] g_MxMW61Mbk: Downloading android player API JSON
# [info] g_MxMW61Mbk: Downloading 1 format(s): 137+251
# [info] Writing video description to: Boating Lesson! - Quotidian - 454 [g_MxMW61Mbk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=g_MxMW61Mbk
# [youtube] g_MxMW61Mbk: Downloading webpage
# [youtube] g_MxMW61Mbk: Downloading android player API JSON
# [info] g_MxMW61Mbk: Downloading subtitles: en
# [info] g_MxMW61Mbk: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Boating Lesson! - Quotidian - 454 [g_MxMW61Mbk].en.vtt
# [download] Destination: Boating Lesson! - Quotidian - 454 [g_MxMW61Mbk].en.vtt
# [download] 100% of   20.68KiB in 00:00:00 at 43.40KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gLGWNqy3oK8
# [youtube] gLGWNqy3oK8: Downloading webpage
# [youtube] gLGWNqy3oK8: Downloading android player API JSON
# [info] gLGWNqy3oK8: Downloading 1 format(s): 137+251
# [info] Writing video description to: Layered Goals! - Quotidian - 455 [gLGWNqy3oK8].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gLGWNqy3oK8
# [youtube] gLGWNqy3oK8: Downloading webpage
# [youtube] gLGWNqy3oK8: Downloading android player API JSON
# [info] gLGWNqy3oK8: Downloading subtitles: en
# [info] gLGWNqy3oK8: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: Layered Goals! - Quotidian - 455 [gLGWNqy3oK8].en.vtt
# [download] Destination: Layered Goals! - Quotidian - 455 [gLGWNqy3oK8].en.vtt
# [download] 100% of   22.31KiB in 00:00:00 at 35.29KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e5e_KMml7so
# [youtube] e5e_KMml7so: Downloading webpage
# [youtube] e5e_KMml7so: Downloading android player API JSON
# [info] e5e_KMml7so: Downloading 1 format(s): 137+251
# [info] Writing video description to: 12 Rules for Life! - Quotidian - 456 [e5e_KMml7so].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e5e_KMml7so
# [youtube] e5e_KMml7so: Downloading webpage
# [youtube] e5e_KMml7so: Downloading android player API JSON
# [info] e5e_KMml7so: Downloading subtitles: en
# [info] e5e_KMml7so: Downloading 1 format(s): 137+251
# [info] Writing video subtitles to: 12 Rules for Life! - Quotidian - 456 [e5e_KMml7so].en.vtt
# [download] Destination: 12 Rules for Life! - Quotidian - 456 [e5e_KMml7so].en.vtt
# [download] 100% of   17.88KiB in 00:00:00 at 58.33KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Tw6umTPTEoE
# [youtube] Tw6umTPTEoE: Downloading webpage
# [youtube] Tw6umTPTEoE: Downloading android player API JSON
# [info] Tw6umTPTEoE: Downloading 1 format(s): 248+251
# [info] Writing video description to: The Fine Print! - Quotidian - 457 [Tw6umTPTEoE].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Tw6umTPTEoE
# [youtube] Tw6umTPTEoE: Downloading webpage
# [youtube] Tw6umTPTEoE: Downloading android player API JSON
# [info] Tw6umTPTEoE: Downloading subtitles: en
# [info] Tw6umTPTEoE: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: The Fine Print! - Quotidian - 457 [Tw6umTPTEoE].en.vtt
# [download] Destination: The Fine Print! - Quotidian - 457 [Tw6umTPTEoE].en.vtt
# [download] 100% of   18.72KiB in 00:00:00 at 29.54KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4hFJ5Rr6E1E
# [youtube] 4hFJ5Rr6E1E: Downloading webpage
# [youtube] 4hFJ5Rr6E1E: Downloading android player API JSON
# [info] 4hFJ5Rr6E1E: Downloading 1 format(s): 248+251
# [info] Writing video description to: The Greater Good! - Quotidian - 458 [4hFJ5Rr6E1E].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4hFJ5Rr6E1E
# [youtube] 4hFJ5Rr6E1E: Downloading webpage
# [youtube] 4hFJ5Rr6E1E: Downloading android player API JSON
# [info] 4hFJ5Rr6E1E: Downloading subtitles: en
# [info] 4hFJ5Rr6E1E: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: The Greater Good! - Quotidian - 458 [4hFJ5Rr6E1E].en.vtt
# [download] Destination: The Greater Good! - Quotidian - 458 [4hFJ5Rr6E1E].en.vtt
# [download] 100% of   20.95KiB in 00:00:00 at 43.35KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L4OKplmEnkk
# [youtube] L4OKplmEnkk: Downloading webpage
# [youtube] L4OKplmEnkk: Downloading android player API JSON
# [info] L4OKplmEnkk: Downloading 1 format(s): 248+251
# [info] Writing video description to: Failing To Learn! - Quotidian - 459 [L4OKplmEnkk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L4OKplmEnkk
# [youtube] L4OKplmEnkk: Downloading webpage
# [youtube] L4OKplmEnkk: Downloading android player API JSON
# [info] L4OKplmEnkk: Downloading subtitles: en
# [info] L4OKplmEnkk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Failing To Learn! - Quotidian - 459 [L4OKplmEnkk].en.vtt
# [download] Destination: Failing To Learn! - Quotidian - 459 [L4OKplmEnkk].en.vtt
# [download] 100% of   23.26KiB in 00:00:00 at 43.76KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sPrUxPyHgeo
# [youtube] sPrUxPyHgeo: Downloading webpage
# [youtube] sPrUxPyHgeo: Downloading android player API JSON
# [info] sPrUxPyHgeo: Downloading 1 format(s): 248+251
# [info] Writing video description to: Q and A for 451 to 459— Quotidian — 460 [sPrUxPyHgeo].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sPrUxPyHgeo
# [youtube] sPrUxPyHgeo: Downloading webpage
# [youtube] sPrUxPyHgeo: Downloading android player API JSON
# [info] sPrUxPyHgeo: Downloading 1 format(s): 248+251
# [info] There's no subtitles for the requested languages
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2fEFM84k8MI
# [youtube] 2fEFM84k8MI: Downloading webpage
# [youtube] 2fEFM84k8MI: Downloading android player API JSON
# [info] 2fEFM84k8MI: Downloading 1 format(s): 248+251
# [info] Writing video description to: Deep Sea Advice! - Quotidian - 461 [2fEFM84k8MI].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2fEFM84k8MI
# [youtube] 2fEFM84k8MI: Downloading webpage
# [youtube] 2fEFM84k8MI: Downloading android player API JSON
# [info] 2fEFM84k8MI: Downloading subtitles: en
# [info] 2fEFM84k8MI: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Deep Sea Advice! - Quotidian - 461 [2fEFM84k8MI].en.vtt
# [download] Destination: Deep Sea Advice! - Quotidian - 461 [2fEFM84k8MI].en.vtt
# [download] 100% of   21.46KiB in 00:00:00 at 54.12KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pGwJN3G_tLk
# [youtube] pGwJN3G_tLk: Downloading webpage
# [youtube] pGwJN3G_tLk: Downloading android player API JSON
# [info] pGwJN3G_tLk: Downloading 1 format(s): 248+251
# [info] Writing video description to: Mental Models! - Quotidian - 462 [pGwJN3G_tLk].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pGwJN3G_tLk
# [youtube] pGwJN3G_tLk: Downloading webpage
# [youtube] pGwJN3G_tLk: Downloading android player API JSON
# [info] pGwJN3G_tLk: Downloading subtitles: en
# [info] pGwJN3G_tLk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Mental Models! - Quotidian - 462 [pGwJN3G_tLk].en.vtt
# [download] Destination: Mental Models! - Quotidian - 462 [pGwJN3G_tLk].en.vtt
# [download] 100% of   20.08KiB in 00:00:00 at 33.13KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UavPtCO8fL4
# [youtube] UavPtCO8fL4: Downloading webpage
# [youtube] UavPtCO8fL4: Downloading android player API JSON
# [info] UavPtCO8fL4: Downloading 1 format(s): 248+251
# [info] Writing video description to: Forever Skills! - Quotidian - 463 [UavPtCO8fL4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UavPtCO8fL4
# [youtube] UavPtCO8fL4: Downloading webpage
# [youtube] UavPtCO8fL4: Downloading android player API JSON
# [info] UavPtCO8fL4: Downloading subtitles: en
# [info] UavPtCO8fL4: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Forever Skills! - Quotidian - 463 [UavPtCO8fL4].en.vtt
# [download] Destination: Forever Skills! - Quotidian - 463 [UavPtCO8fL4].en.vtt
# [download] 100% of   29.26KiB in 00:00:00 at 53.49KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VcUt1uxT9L4
# [youtube] VcUt1uxT9L4: Downloading webpage
# [youtube] VcUt1uxT9L4: Downloading android player API JSON
# [info] VcUt1uxT9L4: Downloading 1 format(s): 248+251
# [info] Writing video description to: Just A Minute! - Quotidian - 464 [VcUt1uxT9L4].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VcUt1uxT9L4
# [youtube] VcUt1uxT9L4: Downloading webpage
# [youtube] VcUt1uxT9L4: Downloading android player API JSON
# [info] VcUt1uxT9L4: Downloading subtitles: en
# [info] VcUt1uxT9L4: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Just A Minute! - Quotidian - 464 [VcUt1uxT9L4].en.vtt
# [download] Destination: Just A Minute! - Quotidian - 464 [VcUt1uxT9L4].en.vtt
# [download] 100% of   30.33KiB in 00:00:00 at 96.09KiB/s
# 0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LBqYUj6J5Y0
# [youtube] LBqYUj6J5Y0: Downloading webpage
# [youtube] LBqYUj6J5Y0: Downloading android player API JSON
# [info] LBqYUj6J5Y0: Downloading 1 format(s): 248+251
# [info] Writing video description to: Signs of Happiness! - Quotidian - 465 [LBqYUj6J5Y0].description
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LBqYUj6J5Y0
# [youtube] LBqYUj6J5Y0: Downloading webpage
# [youtube] LBqYUj6J5Y0: Downloading android player API JSON
# [info] LBqYUj6J5Y0: Downloading subtitles: en
# [info] LBqYUj6J5Y0: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Signs of Happiness! - Quotidian - 465 [LBqYUj6J5Y0].en.vtt
# [download] Destination: Signs of Happiness! - Quotidian - 465 [LBqYUj6J5Y0].en.vtt
# [download] 100% of   19.49KiB in 00:00:00 at 34.12KiB/s

# %%
video.replace('\n', '')
# Out:
# 'FsetSycvEyA'

# %%
os.system("youtube-dl https://www.youtube.com/watch?v="+video.replace('\n', '')+" --write-description --skip-download --youtube-skip-dash-manifest"
)
# Out:
# [youtube] FsetSycvEyA: Downloading webpage
# [info] Writing video description to: Synthesis! - Quotidian - 427-FsetSycvEyA.description
# 0

# %%
os.system("youtube-dl https://www.youtube.com/watch?v="+video.replace('\n', '')+" --write-sub --sub-lang en --skip-download ")
# Out:
# [youtube] FsetSycvEyA: Downloading webpage
# [info] Writing video subtitles to: Synthesis! - Quotidian - 427-FsetSycvEyA.en.vtt
# 0

# %%
transcript = YouTubeTranscriptApi.get_transcript('wDyndmcdDkg')

# %%
transcript
# Out:
# [{'text': 'One of my favourite movies is Pearl Harbour.',
#   'start': 0.71,
#   'duration': 2.97},
#  {'text': 'We have watched this scene once, earlier too!',
#   'start': 3.68,
#   'duration': 3.409},
#  {'text': 'Let’s watch it again!', 'start': 7.089, 'duration': 6.261},
#  {'text': 'When the junior General is appreciating the\nsenior General, the senior says, “I am not',
#   'start': 13.35,
#   'duration': 16.36},
#  {'text': 'really all that brilliant..', 'start': 29.71, 'duration': 1.899},
#  {'text': 'If I were truly brilliant, I would have found\na way not to fight this war!',
#   'start': 31.609,
#   'duration': 5.36},
#  {'text': 'It is no big deal really, winning a war.',
#   'start': 36.969,
#   'duration': 2.27},
#  {'text': 'To prevent it from even happening?',
#   'start': 39.239,
#   'duration': 2.701},
#  {'text': 'That is what deserves credit, perhaps.',
#   'start': 41.94,
#   'duration': 2.709},
#  {'text': 'To not do something.', 'start': 44.649, 'duration': 2.011},
#  {'text': 'A puzzle.', 'start': 46.66, 'duration': 1.31},
#  {'text': 'THREE puzzles in fact.', 'start': 47.97, 'duration': 2.639},
#  {'text': 'That is what we are going to look at, today!',
#   'start': 50.609,
#   'duration': 16.94},
#  {'text': 'Namaste!', 'start': 67.549, 'duration': 5.241},
#  {'text': 'Four hundred and nineteen!', 'start': 72.79, 'duration': 1.11},
#  {'text': 'Remember the three puzzles that I was talking\nabout?',
#   'start': 73.9,
#   'duration': 4.95},
#  {'text': 'They actually started here!', 'start': 78.85, 'duration': 2.78},
#  {'text': 'Zoho Schools — That’s where I spend most\nof my time these days.',
#   'start': 81.63,
#   'duration': 4.9},
#  {'text': 'We have three kinds of schools there.',
#   'start': 86.53,
#   'duration': 3.74},
#  {'text': 'There is a School of Design, a School of Technology,\nand a School of Business.',
#   'start': 90.27,
#   'duration': 5.84},
#  {'text': 'If we were to try and associate a single short\ncute word to each of them, a school where',
#   'start': 96.11,
#   'duration': 7.17},
#  {'text': 'we teach how to CREATE experiences, interfaces…',
#   'start': 103.28,
#   'duration': 4.76},
#  {'text': 'where we teach them how to CODE (those experiences!),\nand… having CREATED it, having CODED it,',
#   'start': 108.04,
#   'duration': 11.189},
#  {'text': 'you need to COMMUNICATE it to the outside\nworld.',
#   'start': 119.229,
#   'duration': 3.411},
#  {'text': 'So, this is what we think we are trying to\ndo at Zoho Schools.',
#   'start': 122.64,
#   'duration': 4.24},
#  {'text': 'I teach at all the three schools, and, recently,\nwhile I was with my students, we encountered',
#   'start': 126.88,
#   'duration': 4.97},
#  {'text': 'something quite unusual.', 'start': 131.85, 'duration': 1.0},
#  {'text': 'In each of the three schools, as part of the\nlessons I was teaching, a paradoxical sentence',
#   'start': 132.85,
#   'duration': 12.87},
#  {'text': 'accosted my eyes.', 'start': 145.72, 'duration': 1.61},
#  {'text': 'Just when I thought it was perhaps specific\nto one domain, we realised that it was being',
#   'start': 147.33,
#   'duration': 7.28},
#  {'text': 'featured in another school too, in an adjoining\ndomain too..!',
#   'start': 154.61,
#   'duration': 3.64},
#  {'text': 'It seemed to be EVERYWHERE!', 'start': 158.25, 'duration': 1.16},
#  {'text': 'What sentence was it?', 'start': 159.41, 'duration': 1.79},
#  {'text': 'Shall we take a look?', 'start': 161.2, 'duration': 2.71},
#  {'text': 'This man — you may not know him.',
#   'start': 163.91,
#   'duration': 2.18},
#  {'text': 'He is still not a man yet in this photo, he\nwas a fifteen year old kid at this time.',
#   'start': 166.09,
#   'duration': 5.0},
#  {'text': 'His name is Rich Skrenta.', 'start': 171.09, 'duration': 2.78},
#  {'text': 'He has the dubious fame for having programmed\nthe first microcomputer virus.',
#   'start': 173.87,
#   'duration': 7.7},
#  {'text': 'The guy who created the first “virus”\nfor personal computers!',
#   'start': 181.57,
#   'duration': 8.6},
#  {'text': 'Today though, he looks like this.',
#   'start': 190.17,
#   'duration': 3.12},
#  {'text': 'His important message to the world, which\nstruck as odd to me, which left me wondering',
#   'start': 193.29,
#   'duration': 5.48},
#  {'text': 'why he was speaking so off the beaten track,\nis this sentence.',
#   'start': 198.77,
#   'duration': 6.3},
#  {'text': 'He said, “Code is our enemy”!', 'start': 205.07, 'duration': 2.91},
#  {'text': 'A programmer, one of the world’s best, we\nmight even call him… he says, “Code is',
#   'start': 207.98,
#   'duration': 5.88},
#  {'text': 'our enemy, and so, don’t create too much\nof it!”',
#   'start': 213.86,
#   'duration': 3.63},
#  {'text': 'You may not recognise this person either,\nbecause he isn’t associated with his real',
#   'start': 217.49,
#   'duration': 5.08},
#  {'text': 'photograph as often as he is identified with\nhis cartoon look.',
#   'start': 222.57,
#   'duration': 4.0},
#  {'text': 'That cartoon image looks like this!',
#   'start': 226.57,
#   'duration': 1.87},
#  {'text': 'Coding Horror is the name of his blog.',
#   'start': 228.44,
#   'duration': 3.22},
#  {'text': 'Jeff Atwood, who became quite famous through\nthis programming-blog “Coding Horror”,',
#   'start': 231.66,
#   'duration': 4.51},
#  {'text': 'is also the person behind Stack Overflow!',
#   'start': 236.17,
#   'duration': 2.67},
#  {'text': 'They even call it the Programmer’s Google!',
#   'start': 238.84,
#   'duration': 7.19},
#  {'text': 'That group of sites called Stack Exchange?',
#   'start': 246.03,
#   'duration': 2.5},
#  {'text': 'He is the cofounder!', 'start': 248.53, 'duration': 4.15},
#  {'text': 'He spouts another similar sentence, just like\nRich Skrenta did.',
#   'start': 252.68,
#   'duration': 11.09},
#  {'text': 'He says, “The Best Code Is No Code At All!”',
#   'start': 263.77,
#   'duration': 6.63},
#  {'text': 'Do you NOT create something consciously?',
#   'start': 270.4,
#   'duration': 2.46},
#  {'text': 'How much do you choose NOT TO DO, in programming?',
#   'start': 272.86,
#   'duration': 4.089},
#  {'text': 'How many lines of code are you able to SAVE\nby not typing them!?',
#   'start': 276.949,
#   'duration': 6.341},
#  {'text': 'That defines how good a programmer you are!',
#   'start': 283.29,
#   'duration': 2.24},
#  {'text': 'Such was the philosophy he proposed.',
#   'start': 285.53,
#   'duration': 3.57},
#  {'text': 'Why did both these people popularise such\na theory about programming?',
#   'start': 289.1,
#   'duration': 5.93},
#  {'text': 'Don’t they sound a bit paradoxical?',
#   'start': 295.03,
#   'duration': 2.33},
#  {'text': 'Well, let us take the example of the Swiss\nArmy Knife.',
#   'start': 297.36,
#   'duration': 4.61},
#  {'text': 'Between the programming world and the manufacturing\nof this Swiss Army Knife, I see some similarities.',
#   'start': 301.97,
#   'duration': 9.11},
#  {'text': 'For example, both the programmer and the Swiss\nArmy Knife manufacturer would be focused on',
#   'start': 311.08,
#   'duration': 7.26},
#  {'text': 'speed of execution.', 'start': 318.34, 'duration': 1.549},
#  {'text': 'If I were to start on a task, how fast can\nI pull it out and pick the right blade or',
#   'start': 319.889,
#   'duration': 5.791},
#  {'text': 'tool, and get the job done?', 'start': 325.68, 'duration': 2.209},
#  {'text': 'That is Speed of Execution.', 'start': 327.889, 'duration': 2.53},
#  {'text': 'Yes.', 'start': 330.419, 'duration': 1.0},
#  {'text': 'Similarly, I will be obsessed about how many\nfeatures my software has.',
#   'start': 331.419,
#   'duration': 7.99},
#  {'text': 'How many different things I can open out from\nmy Swiss Army Knife.',
#   'start': 339.409,
#   'duration': 5.051},
#  {'text': 'And, additionally, I will also be wondering\nif it is flexible enough.',
#   'start': 344.46,
#   'duration': 6.23},
#  {'text': 'New things…', 'start': 350.69, 'duration': 1.0},
#  {'text': 'Even things that the manufacturer didn’t\naccount for when they built it, will a user',
#   'start': 351.69,
#   'duration': 5.289},
#  {'text': 'be able to add it on?', 'start': 356.979, 'duration': 2.421},
#  {'text': 'Extend it?', 'start': 359.4, 'duration': 1.0},
#  {'text': 'If we smartly combine one knife with another,\nwill we get a third tool?',
#   'start': 360.4,
#   'duration': 3.53},
#  {'text': 'Flexibility.', 'start': 363.93, 'duration': 1.0},
#  {'text': 'Related closely with this flexibility, is\nRobustness.',
#   'start': 364.93,
#   'duration': 1.0},
#  {'text': 'A program, or a software tool, when it has\nto perform tasks that it wasn’t originally',
#   'start': 365.93,
#   'duration': 7.989},
#  {'text': 'intended for, stuff that the creator would\nbe hollering “I didn’t create this with',
#   'start': 373.919,
#   'duration': 6.481},
#  {'text': 'your requirement in mind!”, when the user\nsays, “I am using this for something else,',
#   'start': 380.4,
#   'duration': 5.819},
#  {'text': 'like one uses a pencil to look for earwax!',
#   'start': 386.219,
#   'duration': 3.35},
#  {'text': 'I have paid you, who are you to question me?',
#   'start': 389.569,
#   'duration': 4.28},
#  {'text': 'I will use it for unusual things!”',
#   'start': 393.849,
#   'duration': 2.331},
#  {'text': 'So, if it were to tackle these gracefully,\nnot break at the monkey-mischief that the',
#   'start': 396.18,
#   'duration': 4.699},
#  {'text': 'user does on the software / knife, if it withstands\nwithout breaking or misbehaving, THAT is robustness!',
#   'start': 400.879,
#   'duration': 6.701},
#  {'text': 'And of course, how brief is it?',
#   'start': 407.58,
#   'duration': 3.61},
#  {'text': 'How cute and compact?', 'start': 411.19, 'duration': 1.699},
#  {'text': 'And, finally, how long did you take to deliver\nit?',
#   'start': 412.889,
#   'duration': 4.4},
#  {'text': 'I wanted a simple knife, you took two years\nto manufacture a Swiss Army Knife?',
#   'start': 417.289,
#   'duration': 4.88},
#  {'text': 'While I just wanted a knife to cut bread?',
#   'start': 422.169,
#   'duration': 4.27},
#  {'text': 'Speed of Development!', 'start': 426.439, 'duration': 1.0},
#  {'text': 'In the world of a programmer though, the ironic\nsituation is that these six things we just',
#   'start': 427.439,
#   'duration': 9.38},
#  {'text': 'listed are pulling the deadline and the schedule\nin completely different directions!',
#   'start': 436.819,
#   'duration': 6.22},
#  {'text': 'If you try to optimise on one of them, you\nwill have to sacrifice a couple of others.',
#   'start': 443.039,
#   'duration': 7.68},
#  {'text': 'And THAT IS WHY Jeff Atwood is asking us to\nplease focus on Brevity of Code.',
#   'start': 450.719,
#   'duration': 6.06},
#  {'text': 'Simplify!', 'start': 456.779, 'duration': 1.0},
#  {'text': 'Make it shorter, smoother, cuter!',
#   'start': 457.779,
#   'duration': 3.521},
#  {'text': 'Let us think about everything else LATER.',
#   'start': 461.3,
#   'duration': 4.119},
#  {'text': 'Reduce the fluff.', 'start': 465.419, 'duration': 1.47},
#  {'text': 'Compact it!', 'start': 466.889, 'duration': 1.581},
#  {'text': 'The best code is the code that hasn’t been\nwritten!',
#   'start': 468.47,
#   'duration': 4.89},
#  {'text': 'Alright, that’s the CODE world.',
#   'start': 473.36,
#   'duration': 3.51},
#  {'text': 'What about the CREATE world?', 'start': 476.87, 'duration': 3.129},
#  {'text': 'We were talking about “Design”.',
#   'start': 479.999,
#   'duration': 3.28},
#  {'text': 'Consider this example.', 'start': 483.279, 'duration': 1.0},
#  {'text': 'We have a package that has arrived.',
#   'start': 484.279,
#   'duration': 2.39},
#  {'text': 'And THIS is what I want to achieve before\nmy wife comes home…',
#   'start': 486.669,
#   'duration': 4.53},
#  {'text': 'I want to hang that beautiful painting on\nthe wall.',
#   'start': 491.199,
#   'duration': 4.451},
#  {'text': 'And I need a tool…', 'start': 495.65, 'duration': 3.12},
#  {'text': 'From here to there, I have to reach.',
#   'start': 498.77,
#   'duration': 1.81},
#  {'text': 'And the tool is just for that purpose.',
#   'start': 500.58,
#   'duration': 5.089},
#  {'text': 'We have to realise that the tool is very important,\nbut the tool is not the end goal.',
#   'start': 505.669,
#   'duration': 6.901},
#  {'text': 'We can’t ogle at the tool and say, “Oh,\nhow beautifully designed!',
#   'start': 512.57,
#   'duration': 5.08},
#  {'text': 'How colorful the interface is!', 'start': 517.65, 'duration': 1.42},
#  {'text': 'How heavy!', 'start': 519.07, 'duration': 1.0},
#  {'text': '(Or how light!)', 'start': 520.07, 'duration': 1.0},
#  {'text': 'How safe!', 'start': 521.07, 'duration': 1.0},
#  {'text': 'We will not be obsessing about the tool…',
#   'start': 522.07,
#   'duration': 3.77},
#  {'text': 'Because, The Best Design Is No Design at all!',
#   'start': 525.84,
#   'duration': 4.7},
#  {'text': 'Between a user and the problem that the user\nis facing… and the solution that the user',
#   'start': 530.54,
#   'duration': 9.76},
#  {'text': 'is looking to reach…', 'start': 540.3, 'duration': 2.39},
#  {'text': 'The intervening OBSTACLE, the temporary DISTRACTION,\nis design.',
#   'start': 542.69,
#   'duration': 5.41},
#  {'text': 'Get lost!', 'start': 548.1, 'duration': 1.97},
#  {'text': 'Get out of my way!', 'start': 550.07, 'duration': 2.59},
#  {'text': 'Let me reach my destination faster!',
#   'start': 552.66,
#   'duration': 3.91},
#  {'text': 'It should actually be.. like this!',
#   'start': 556.57,
#   'duration': 3.03},
#  {'text': 'The tool should be insignificant.',
#   'start': 559.6,
#   'duration': 1.76},
#  {'text': 'Shouldn’t take your mind time.', 'start': 561.36, 'duration': 4.01},
#  {'text': 'Look at these examples.', 'start': 565.37, 'duration': 1.44},
#  {'text': 'At an ATM, you enter, you swipe, you withdraw,\nyou exit!',
#   'start': 566.81,
#   'duration': 3.96},
#  {'text': 'Do you ever stop to appreciate how beautiful,\nsturdy, and intuitively the ATM machine is',
#   'start': 570.77,
#   'duration': 5.27},
#  {'text': 'designed?', 'start': 576.04, 'duration': 1.0},
#  {'text': 'How about attaching a file?', 'start': 577.04, 'duration': 1.55},
#  {'text': 'You are uploading something.', 'start': 578.59, 'duration': 1.7},
#  {'text': 'You drag and drop it..', 'start': 580.29, 'duration': 1.04},
#  {'text': 'It just goes up to the cloud and says Done.',
#   'start': 581.33,
#   'duration': 2.25},
#  {'text': 'In fact, some upload mechanisms allow you\nto do something else while the upload happens',
#   'start': 583.58,
#   'duration': 5.35},
#  {'text': 'in the background.', 'start': 588.93, 'duration': 1.59},
#  {'text': 'THAT is getting out of the way!',
#   'start': 590.52,
#   'duration': 3.32},
#  {'text': 'Opening a can..!', 'start': 593.84, 'duration': 1.0},
#  {'text': 'A can opener.', 'start': 594.84, 'duration': 1.0},
#  {'text': 'We are curious about what is inside..',
#   'start': 595.84,
#   'duration': 1.0},
#  {'text': 'We want to gobble up the Gulab Jamoons inside,\nas fast as possible!',
#   'start': 596.84,
#   'duration': 3.27},
#  {'text': 'See how beautifully designed this is?!',
#   'start': 600.11,
#   'duration': 1.57},
#  {'text': 'It has a can opener attached to it too!',
#   'start': 601.68,
#   'duration': 1.97},
#  {'text': 'There is a baby-proof mechanism too.',
#   'start': 603.65,
#   'duration': 3.08},
#  {'text': 'Yes, thank you, but I don’t want to hear\nabout it!',
#   'start': 606.73,
#   'duration': 4.2},
#  {'text': 'How about saving a number..', 'start': 610.93, 'duration': 2.22},
#  {'text': 'A new number.', 'start': 613.15, 'duration': 1.0},
#  {'text': 'You meet somebody, you want to add them to\nyour contacts.',
#   'start': 614.15,
#   'duration': 1.11},
#  {'text': 'How hard it is, to add a number.',
#   'start': 615.26,
#   'duration': 1.63},
#  {'text': 'We have to tap Create.', 'start': 616.89, 'duration': 1.26},
#  {'text': 'If you don’t give some specific details,\nit won’t let you save.',
#   'start': 618.15,
#   'duration': 3.14},
#  {'text': 'It will throw errors.', 'start': 621.29, 'duration': 1.37},
#  {'text': 'And, that guy is looking at our antics all\nthe time!',
#   'start': 622.66,
#   'duration': 4.18},
#  {'text': 'Why can’t it be as simple as we get their\nphone number, and voila, it is done!?',
#   'start': 626.84,
#   'duration': 5.5},
#  {'text': 'Get out of my way!', 'start': 632.34, 'duration': 1.1},
#  {'text': 'Many among us haven’t yet understood and\ninternalised that design philosophy.',
#   'start': 633.44,
#   'duration': 5.41},
#  {'text': 'Google has understood it.', 'start': 638.85, 'duration': 1.84},
#  {'text': 'Google optimises to minimise the time you\nspend at Google!',
#   'start': 640.69,
#   'duration': 4.5},
#  {'text': 'You are looking for something..?',
#   'start': 645.19,
#   'duration': 2.17},
#  {'text': 'Well, the reason the Google interface hasn’t\nchanged at all?',
#   'start': 647.36,
#   'duration': 6.39},
#  {'text': 'They don’t want to add bells and whistles!',
#   'start': 653.75,
#   'duration': 4.07},
#  {'text': 'They just want to get out of the way, so that,\nyour search query, instantaneously almost,',
#   'start': 657.82,
#   'duration': 8.44},
#  {'text': 'gives the answers, and keeps going on!',
#   'start': 666.26,
#   'duration': 2.0},
#  {'text': 'So, the best design?', 'start': 668.26, 'duration': 2.46},
#  {'text': 'Is no design at all!', 'start': 670.72, 'duration': 3.79},
#  {'text': 'And, in the world of marketing?',
#   'start': 674.51,
#   'duration': 3.31},
#  {'text': 'In the world of communication?', 'start': 677.82, 'duration': 1.05},
#  {'text': 'Getting the word across?', 'start': 678.87, 'duration': 1.73},
#  {'text': 'Spreading the word?', 'start': 680.6, 'duration': 3.02},
#  {'text': 'The Best Marketing Is No Marketing At All!',
#   'start': 683.62,
#   'duration': 4.11},
#  {'text': 'Hugh Macleod, great blogger, author, philosopher\nin my opinion, we have encountered a few cartoons',
#   'start': 687.73,
#   'duration': 7.23},
#  {'text': 'from him in the past, he says this..',
#   'start': 694.96,
#   'duration': 3.49},
#  {'text': '“If you talk to people the way advertising\ntalked to people, … “ What would happen?',
#   'start': 698.45,
#   'duration': 7.94},
#  {'text': '“They would punch you in the face!”',
#   'start': 706.39,
#   'duration': 3.74},
#  {'text': '(won’t they!)', 'start': 710.13, 'duration': 1.06},
#  {'text': 'Why are there so many Apps?', 'start': 711.19, 'duration': 3.21},
#  {'text': 'So many browsers?', 'start': 714.4, 'duration': 1.6},
#  {'text': 'Ad Blocker!', 'start': 716.0, 'duration': 1.84},
#  {'text': 'Ad Blocker Plus!', 'start': 717.84, 'duration': 1.12},
#  {'text': 'I noticed this quirk recently!', 'start': 718.96, 'duration': 2.5},
#  {'text': 'There are Blockers for Ads that are shown\nby Ad Blockers!!',
#   'start': 721.46,
#   'duration': 7.05},
#  {'text': 'Why?!', 'start': 728.51, 'duration': 1.0},
#  {'text': 'We have grown in a world where we thought\nadvertising means interrupting.',
#   'start': 729.51,
#   'duration': 7.46},
#  {'text': '“You are doing something.', 'start': 736.97, 'duration': 2.23},
#  {'text': 'You are doing it for free.', 'start': 739.2, 'duration': 1.08},
#  {'text': 'For having allowed you to do it for free,\nwe are going to force you to watch an Ad.',
#   'start': 740.28,
#   'duration': 8.65},
#  {'text': 'Listen to my message.', 'start': 748.93, 'duration': 1.82},
#  {'text': 'Fill out my form.”', 'start': 750.75, 'duration': 1.82},
#  {'text': 'That’s not the world we are in today!',
#   'start': 752.57,
#   'duration': 2.72},
#  {'text': 'That interruption-driven marketing has lived\nout its lifespan!',
#   'start': 755.29,
#   'duration': 4.83},
#  {'text': '“Trust Me!”, says this guy.', 'start': 760.12, 'duration': 2.45},
#  {'text': 'Will you trust this person?', 'start': 762.57, 'duration': 2.08},
#  {'text': '“Trust me!', 'start': 764.65, 'duration': 1.0},
#  {'text': 'I am the sales guy!”', 'start': 765.65, 'duration': 2.47},
#  {'text': 'Why?', 'start': 768.12, 'duration': 1.0},
#  {'text': 'Why are we not able to trust?', 'start': 769.12, 'duration': 1.99},
#  {'text': 'Because, this person is looking for the quick\ndeal.',
#   'start': 771.11,
#   'duration': 3.24},
#  {'text': 'Overnight, he just wants to up and leave..\nfor only the day after tomorrow, you are going',
#   'start': 774.35,
#   'duration': 8.52},
#  {'text': 'to learn that the product is broken.',
#   'start': 782.87,
#   'duration': 4.05},
#  {'text': 'But no, those times are gone!', 'start': 786.92, 'duration': 2.47},
#  {'text': 'Today, we live in a world where we talk about\nthe ‘Lifetime Value of a Customer’.',
#   'start': 789.39,
#   'duration': 4.97},
#  {'text': 'All life long, we need to build a relationship.',
#   'start': 794.36,
#   'duration': 2.26},
#  {'text': 'We want that person to come back to us to\nbuy once again.',
#   'start': 796.62,
#   'duration': 4.49},
#  {'text': 'We expect them to come to us to purchase the\nOTHER things that we sell too!',
#   'start': 801.11,
#   'duration': 5.19},
#  {'text': 'Not just that, if they like the product, they\nwill wilfully and for free, drag their brothers,',
#   'start': 806.3,
#   'duration': 5.47},
#  {'text': 'sisters, uncles, relatives, friends, and he\nwill spread the word..',
#   'start': 811.77,
#   'duration': 4.17},
#  {'text': '“Be our agent!”', 'start': 815.94, 'duration': 1.25},
#  {'text': '— we expect of them!', 'start': 817.19, 'duration': 1.67},
#  {'text': 'If that is what you are looking for as a marketer,\nit is all about relationships, and you need',
#   'start': 818.86,
#   'duration': 7.36},
#  {'text': 'to swipe interruptions off the table!',
#   'start': 826.22,
#   'duration': 7.01},
#  {'text': 'Marketing should not probably be done AT ALL!',
#   'start': 833.23,
#   'duration': 4.19},
#  {'text': 'There is a book titled “This is Marketing”,\nby our esteemed friend Seth Godin.',
#   'start': 837.42,
#   'duration': 5.83},
#  {'text': 'I bumped into two very beautifully written\nsentences.',
#   'start': 843.25,
#   'duration': 2.86},
#  {'text': 'I wanted to share them with you!',
#   'start': 846.11,
#   'duration': 2.57},
#  {'text': 'The first one says, “The shortcuts using\nmoney, to buy attention to sell average stuff',
#   'start': 848.68,
#   'duration': 9.45},
#  {'text': 'to average people are an artifact of another\ntime, not the one we live in now!”',
#   'start': 858.13,
#   'duration': 17.62},
#  {'text': 'What is the time today then?', 'start': 875.75, 'duration': 3.2},
#  {'text': 'He says, you have to do this, if you want\nto be a marketer!',
#   'start': 878.95,
#   'duration': 3.373},
#  {'text': 'Learn to see how humans dream, decide, act!',
#   'start': 882.323,
#   'duration': 9.357},
#  {'text': 'Observe this!', 'start': 891.68, 'duration': 2.3},
#  {'text': 'Watch this!', 'start': 893.98, 'duration': 1.05},
#  {'text': 'Learn about these behaviours!', 'start': 895.03, 'duration': 3.44},
#  {'text': 'And, having done that, he adds, “Help them\nbecome ',
#   'start': 898.47,
#   'duration': 15.78},
#  {'text': 'better versions of themselves, the ones they\nseek to be!”',
#   'start': 914.25,
#   'duration': 5.36},
#  {'text': 'THAT is being a marketer!', 'start': 919.61, 'duration': 2.15},
#  {'text': 'Where is space now, for marketing, here?!',
#   'start': 921.76,
#   'duration': 3.99},
#  {'text': 'And, that brings me to the Closing Thought,\ntoday.',
#   'start': 925.75,
#   'duration': 4.94},
#  {'text': 'This is from Christopher Robin and Winnie\nthe Pooh!',
#   'start': 930.69,
#   'duration': 4.09},
#  {'text': 'Wow!', 'start': 934.78, 'duration': 1.84},
#  {'text': 'What a beautiful quote!', 'start': 936.62, 'duration': 1.32},
#  {'text': 'It goes like this!', 'start': 937.94, 'duration': 1.57},
#  {'text': '“People say nothing is impossible, but I\ndo nothing every day!”, and guess why “doing',
#   'start': 939.51,
#   'duration': 11.82},
#  {'text': 'nothing” is so important?', 'start': 951.33, 'duration': 1.69},
#  {'text': '“I do nothing every day, and doing nothing\noften leads to the very best of something!”',
#   'start': 953.02,
#   'duration': 8.17},
#  {'text': 'Because, when you stop, and think, you probably\nmight come up with a better idea!',
#   'start': 961.19,
#   'duration': 9.11},
#  {'text': 'So, No Design Is Probably The Best Design!',
#   'start': 970.3,
#   'duration': 4.24},
#  {'text': 'The Best Code Is Probably The One That Doesn’t\nGet Written!',
#   'start': 974.54,
#   'duration': 4.5},
#  {'text': 'And, Marketing Will Not Be Called Marketing\nAny More!',
#   'start': 979.04,
#   'duration': 5.47},
#  {'text': 'Thanks a lot!', 'start': 984.51, 'duration': 1.56},
#  {'text': 'Oh…', 'start': 986.07, 'duration': 1.0},
#  {'text': 'Today itself, in a short while from now, we\nwill meet again!',
#   'start': 987.07,
#   'duration': 11.39},
#  {'text': 'Thank you!', 'start': 998.46, 'duration': 1.36}]
